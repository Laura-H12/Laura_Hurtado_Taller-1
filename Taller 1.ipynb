# %% [markdown]
# # Taller #1
#
# #### Laura Daniela Hurtado Davila
#
# #### 2248533

# %% [markdown]
# **1. Perfil de demanda horaria de transmilenio**
#
# La primera visualizacion fue realizada por TRANSMILENIO S.A. para mostrar la demanda diaria en la cuarentena en el componente troncal y zonal, en especial el perfil de demnada horaria de Transmilenio. La visualizacion fue obtenida de la pagina oficial del Transmilenio [en este link](https://www.transmilenio.gov.co/publicaciones/151647/reduccion-de-demanda-en-transmilenio-para-enfrentar-el-covid-19/).

# %% [markdown]
# ![tm.png](attachment:tm.png)

# %% [markdown]
# 1)
#
# **¿QUÉ?**
#
# Los datos que hay en la visualizacion son cualitativos y muestran el numero de validaciones por hora que se presentan en el sistema.
#
# Dataset Types: Temporal.
#
# Data Types: Attributes.
#
# Dataset Availability: Dynamic.
#
# Tipo de Atributo: Ordering direction, Sequential.
#
# **¿POR QUÉ?**
#
# Verbo: Analyze, Consume, Present. Query, Compare.
#
# Sustantivo: All data, Trends. Attributes, Many, Similarity.
#
# **¿CÓMO?**
#
# Facet, Superimpose.

# %% [markdown]
# 2)
# **Marca**
#
# Marca de puntos.
#
# **Canal**
#
# Canal de posicion espacial, vertical para numero de validaciones y horizontal para la hora.
#
# Al tener atributos categoricos tiene un Ranking de canal color hue.

# %% [markdown]
# 3)
#
# De las reglas generales descritas a esta visualizacion no le aplica niguna.

# %% [markdown]
# 4)
#
# Un cambio que desde mi punto de vista se le podria hacer a la visualizacion son los shapes en cada parte de la grafica para que sea mas clara la division entre los datos de la semana pasada y el dia en desarrollo.

# %% [markdown]
# **2. Mapping Poverty in America**
#
# La segunda visualizacion fue realizada por The New York Times para mostrar un mapeo de la pobreza de los Estados Unidos y asi ver en que zona viven las personas con una menor calidad de vida, . La visualizacion fue obtenida de la pagina oficial del The New York Times [en este link](https://www.nytimes.com/newsgraphics/2014/01/05/poverty-map/index.html).

# %% [markdown]
# ![mapa.png](attachment:mapa.png)

# %% [markdown]
# 1)
#
# **¿QUÉ?**
#
# Los datos que hay en la visualizacion son cualitativos y muestran el nivel de vida que tienen las personas en cada estado.
#
# Dataset Types: Geometry.
#
# Data Types: Positions.
#
# Dataset Availability: Static.
#
# Tipo de Atributo: Attribute Types, Ordered, Quantitative.
#
# **¿POR QUÉ?**
#
# Verbo: Analyze, Consume, Present. Search, Explore.
#
# Sustantivo: Spatial data, Shape.
#
# **¿CÓMO?**
#
# Encode, Map, Color Saturation.

# %% [markdown]
# 2)
#
# **Marca**
#
# Marca de area.
#
# **Canal**
#
# Canal de color saturation para ver donde hay mayor concentracion de personas de menores recursos.

# %% [markdown]
# 3)
#
# Para esta vizualizacion solo aplica el zoom y lo cumple.

# %% [markdown]
# 4)
#
# Un cambio para esta visualizacio podria ser un cambio de color pues la escala de tonos azules se relaciona con temas de temperaturas bajas.

# %% [markdown]
# ![mappa.png](attachment:mappa.png)

# %% [markdown]
# **3. Subsidios que han recibido las mujeres desplazadas**
#
# La tercera visualizacion fue realizada por el ministerio de salud para mostrar un mapeo un porcentaje de las mujeres que fueron vistimas del desplazamiento forzado recibieron alguntipo de subsidio. La visualizacion fue obtenida de la pagina oficial del ministerio de salud [en este link](https://www.minsalud.gov.co/sites/rid/Lists/BibliotecaDigital/RIDE/INEC/IGUB/violencia-intrafamiliar-sexual-desplazamiento-forzado.pdf).

# %% [markdown]
# ![barras.png](attachment:barras.png)

# %% [markdown]
# 1)
#
# **¿QUÉ?**
#
# Los datos que hay en la visualizacion son cualitativos y muestran el porcentaje de mujeres que recibieron algun tipo de subsidio lueo de ser victimas de desplazamiento.
#
# Dataset Types: Tables.
#
# Data Types: Attributes .
#
# Dataset Availability: Static.
#
# Tipo de Atributo: Attribute Types, Ordered, Quantitative.
#
# **¿POR QUÉ?**
#
# Verbo: Analyze, Consume, Present. Query, Compare.
#
# Sustantivo: Attributes, Many, Similarity.
#
# **¿CÓMO?**
#
# Encode, Arrange, Aling. Encode, Arrange, Color.

# %% [markdown]
# 2)
#
# **Marca**
#
# Marca de linea.
#
# **Canal**
#
# Canal de posicion espacial vertical para la parte cualitativa y canal de posicion espacial horizontal para la parte cuantitativa. Canal de color para la categoria.

# %% [markdown]
# 3)
#
# Para esta visualizacion solo aplica el 2D pero en este caso es jstificado.

# %% [markdown]
# 4)
#
# Un cambio podria hacerse seria en el canal de color para hacer un mejor contraste de colores y asi hacerla mas llamativa.
